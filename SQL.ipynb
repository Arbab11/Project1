# %%
import mysql.connector
import pandas as pd

# %%
conn=mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
df=pd.read_sql_query("SELECT * FROM city",conn)

# %%
df
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
pd.read_sql_query("SELECT * FROM country",conn)
# Out:
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# 235  YUG    Yugoslavia         Europe            Southern Europe     102173.0
# 236  ZAF  South Africa         Africa            Southern Africa    1221037.0
# 237  ZMB        Zambia         Africa             Eastern Africa     752618.0
# 238  ZWE      Zimbabwe         Africa             Eastern Africa     390757.0
#
# ...

# %%
pd.read_sql_query("SELECT * FROM country WHERE Population > 1000000",conn)
# Out:
#     Code                  Name      Continent                     Region  \
# 0    AFG           Afghanistan           Asia  Southern and Central Asia
# 1    AGO                Angola         Africa             Central Africa
# 2    ALB               Albania         Europe            Southern Europe
# 3    ARE  United Arab Emirates           Asia                Middle East
# 4    ARG             Argentina  South America              South America
# ..   ...                   ...            ...                        ...
# 149  YEM                 Yemen           Asia                Middle East
# 150  YUG            Yugoslavia         Europe            Southern Europe
# 151  ZAF          South Africa         Africa            Southern Africa
# 152  ZMB                Zambia         Africa             Eastern Africa
# 153  ZWE              Zimbabwe         Africa             Eastern Africa
#
#      SurfaceArea  IndepYear  Population  LifeExpectancy       GNP    GNPOld  \
# ...

# %%
pd.read_sql_query("SELECT * FROM country WHERE Region = Middle East",conn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\anaconda3\envs\MLtutorial\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# ~\anaconda3\envs\MLtutorial\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#
# ~\anaconda3\envs\MLtutorial\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     489             query = query.encode('utf-8')
# --> 490         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     491
#
# ...

# %%
pd.read_sql_query("SELECT * FROM country WHERE Region = Middle East",conn)
